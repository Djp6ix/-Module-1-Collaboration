# %% [markdown]
# 11.1 Create a file fcalled zoo.py. in it, define a function called hours() that prints taht string 'Open 9-5 daily'. Then, use the interactive interpreter to import the zoo module and call its hours() function.

# %%
# %%writefile zoo.py
def hours():
    print("Open 9-5 daily")
# Out:
# Overwriting zoo.py

# %%
import zoo 
zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# 11.2 In the interactive interpreter, import the zoo module as menagerie and call its hours() function.

# %%
import zoo as menagerie 
menagerie.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# 16.8 Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 16.4. As in 16.6, select and print the title column from the book table in alphabetical order.

# %%
import csv

# Writing the file
with open("books.csv","w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["writer", "book"])
    writer.writerow(["J. K. Rowling", "Harry Potter"])
    writer.writerow(["J. R. R. Tolkien", "Lord of the Rings"])
    writer.writerow(["C. S. Lewis", "Chronicales of Narnia"])

# %%
import csv

with open("books.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['writer', 'book']
# ['J. K. Rowling', 'Harry Potter']
# ['J. R. R. Tolkien', 'Lord of the Rings']
# ['C. S. Lewis', 'Chronicales of Narnia']
