# %%
# Superclass Vehicle
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

# Subclass Automobile (inherits from Vehicle)
class Automobile(Vehicle):
    def __init__(self, vehicle_type, year, make, model, doors, roof):
        super().__init__(vehicle_type)
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof


# -------- APP STARTS HERE ---------

# Set vehicle type automatically
vehicle_type = "car"

# Gather user input 
year = input("Enter the year of the car: ")
make = input("Enter the make of the car: ")
model = input("Enter the model of the car: ")
doors = input("Enter the number of doors (2 or 4): ")
roof = input("Enter type of roof (solid or sun roof): ")

# Create Automobile object
car = Automobile(vehicle_type, year, make, model, doors, roof)

#-------- OUTPUT --------
print("\n--- Vehicle Information ---")
print(f"Vehicle type: {car.vehicle_type}")
print(f"Year: {car.year}")
print(f"Make: {car.make}")
print(f"Model: {car.model}")
print(f"Number of doors: {car.doors}")
print(f"Type of roof: {car.roof}")
# Out:
# Enter the year of the car:  Toyota
# Enter the make of the car:  Corolla
# Enter the model of the car:  Corolla
# Enter the number of doors (2 or 4):  2
# Enter type of roof (solid or sun roof):  sun roof
# --- Vehicle Information ---
# Vehicle type: car
# Year: Toyota
# Make: Corolla
# Model: Corolla
# Number of doors: 2
# Type of roof: sun roof
